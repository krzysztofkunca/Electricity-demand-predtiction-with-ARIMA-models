# %% [markdown]
# ## model: dzien roboczy- swieto, godzinowo

# %% [markdown]
# ### getting data

# %%
import pandas as pd
from datetime import date
import datetime
import numpy as np
from dateutil.relativedelta import relativedelta
from matplotlib import pyplot as plt

weather_start_year = 2010
end_dt = '2019-03-31'
# #2 months:
# start_dt = '2019-02-01'

#6 months:
# start_dt = '2018-10-01'

# 12 months:
# start_dt = '2018-04-01'

# #24 months:
# start_dt = '2017-04-01'

# # #60 months:
start_dt = '2010-04-01'

weekdays =['Pon', 'Wt', 'Sr', 'Czw', 'Pt', 'Sb', 'Nd']

def dzienTyg(dzienNum):
    if dzienNum == 0:
        return 'Pon'
    elif dzienNum == 1:
        return 'Wt'
    elif dzienNum == 2:
        return 'Sr'
    elif dzienNum == 3:
        return 'Czw'
    elif dzienNum == 4:
        return 'Pt'
    elif dzienNum == 5:
        return 'Sb'
    elif dzienNum == 6:
        return 'Nd'
    else:
        return 'Blad'
def date_fromisofromat(dt):
    y = int(dt[0: 4])
    m = int(dt[5: 7])
    d = int(dt[8:10])
    return date(y,m,d)

def combineData(start, end):
    startDt = date_fromisofromat(start)
    endDt   = date_fromisofromat(end)
    d = datetime.timedelta(days=1)
    m = relativedelta(months=+1)

    in_table = pd.read_csv(filepath_or_buffer= '../../Data/20100301-20100331.csv', 
                       sep=';', 
                       engine='python')
    in_table= in_table.iloc[0:0] #drop all rows, leave columns

    while(startDt <= endDt):
        fileName = str(startDt).replace('-','') + '-' + str(startDt + m - d).replace('-','') + '.csv'
        in_table1 = pd.read_csv(filepath_or_buffer= '../../Data/' +fileName, 
                           sep=';', 
                           engine='python')
        in_table = in_table.append(in_table1,ignore_index=True)
        startDt = startDt + relativedelta(months=+1)

    in_table['Krajowe zapotrzebowanie na moc'] = in_table['Krajowe zapotrzebowanie na moc'].apply(lambda x: x.replace(',','.'))
    in_table['Krajowe zapotrzebowanie na moc'] = in_table['Krajowe zapotrzebowanie na moc'].astype(float)
    in_table['Rok']     = in_table['Data'].apply(lambda x: x[0: 4]).astype(int)
    in_table['Miesiac'] = in_table['Data'].apply(lambda x: x[5: 7]).astype(int)
    in_table['Dzien']   = in_table['Data'].apply(lambda x: x[8:10]).astype(int)
    # in_table['Godz_mies']=(in_table['Dzien']-1)*24 +in_table['Godzina']
    return in_table
#     plt.show()
# Data, Godzina, Krajowe zapotrzebowanie na moc, Sumaryczna generacja JWCD, 
# Generacja PI, Generacja IRZ, Sumaryczna generacja nJWCD, 
# Krajowe saldo wymiany międzysystemowej równoległej, 
# Krajowe saldo wymiany międzysystemowej nierównoległej, 

dataAll = combineData(start_dt, end_dt)
dataAll = dataAll.loc[dataAll['Godzina'] != '2A']

dataAll['Godzina'] = dataAll['Godzina'].apply(
    lambda x: (int(str(x)))
)
dataAll['weekDayNum'] = dataAll['Data'].apply(
    lambda x: (date_fromisofromat(x).weekday())
)
dataAll['weekDay'] = dataAll['Data'].apply(
    lambda x: dzienTyg(date_fromisofromat(x).weekday())
)
dataAll['DataGodz'] = pd.to_datetime(dataAll['Data']) 

dataAll['DataGodz'] = dataAll['DataGodz'] + dataAll['Godzina'].apply(
    lambda x: relativedelta(hours=x)
)
    
modelData = dataAll[['Krajowe zapotrzebowanie na moc']]

#For Arima:
modelData2 = dataAll[['Krajowe zapotrzebowanie na moc',
                      'DataGodz']] 
modelData2.set_index('DataGodz')
modelData2.index = pd.DatetimeIndex(modelData2['DataGodz'])#.to_period('H')

modelData2
# Out:
# D:\Programy\anaconda\lib\site-packages\pandas\core\arrays\datetimelike.py:1345: PerformanceWarning: Adding/subtracting object-dtype array to DatetimeArray not vectorized
#   PerformanceWarning,
#                      Krajowe zapotrzebowanie na moc            DataGodz
# DataGodz
# 2010-04-01 01:00:00                       15280.575 2010-04-01 01:00:00
# 2010-04-01 02:00:00                       14563.425 2010-04-01 02:00:00
# 2010-04-01 03:00:00                       14213.113 2010-04-01 03:00:00
# 2010-04-01 04:00:00                       14156.688 2010-04-01 04:00:00
# 2010-04-01 05:00:00                       14338.525 2010-04-01 05:00:00
# ...                                             ...                 ...
# 2019-03-31 20:00:00                       18097.938 2019-03-31 20:00:00
# 2019-03-31 21:00:00                       18774.000 2019-03-31 21:00:00
# 2019-03-31 22:00:00                       17979.813 2019-03-31 22:00:00
# 2019-03-31 23:00:00                       17091.150 2019-03-31 23:00:00
# 2019-04-01 00:00:00                       15995.775 2019-04-01 00:00:00
#
# [78875 rows x 2 columns]

# %%
dataAll
#For Arima:
modelData2 = dataAll[['Krajowe zapotrzebowanie na moc',
                      'DataGodz','weekDay']] 
# modelData2.set_index('DataGodz')
# modelData2.index = pd.DatetimeIndex(modelData2['DataGodz'])#.to_period('H')

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima
from datetime import datetime

from statsmodels.tsa.seasonal import seasonal_decompose
def create_model(dane, sezon, maxiter = 20, regresor = None):
    start = datetime.now()

    #auto ARIMA
    m = auto_arima(dane, 
           seasonal = True, 
           m=sezon, 
           maxiter = maxiter,
           trace = True,
           exogenous = regresor)#.summary()
    print('autoARIMA time: ' + str(datetime.now() - start))
    order = m.get_params()['order']
    seasonal_order = m.get_params()['seasonal_order']
    print(order)
    print(seasonal_order)
    #SARIMAX
    fit_start =  datetime.now()
    model = SARIMAX(dane, order=order, seasonal_order=seasonal_order, initialization='approximate_diffuse', exog=regresor)
    model_fit = model.fit() 
    
    print('fit time = ' + str(datetime.now() - fit_start))
    return model_fit

# %% [markdown]
# ### Dane pogodowe

# %%
weather_cols = [
'Kod stacji'
,'Nazwa stacji'
,'Rok' 
,'Miesiąc' 
,'Dzień'
,'Godzina' 
,'Wysokość podstawy chmur CL CM szyfrowana [kod]'
,'Status pomiaru HPOD' 
,'Wysokość podstawy niższej  [m]'
,'Status pomiaru HPON' 
,'Wysokość podstawy wyższej [m]'
,'Status pomiaru HPOW' 
,'Wysokość podstawy tekstowy [opis]' 
,'Pomiar przyrzadem 1 (niższa) [P]'
,'Pomiar przyrzadem 2 (wyższa) [P]'
,'Widzialność  [kod]' 
,'Satus pomiaru WID' 
,'Widzialność operatora [m]' 
,'Status pomiaru WIDO' 
,'Widzialność automat [m]'
,'Status pomiaru WIDA' 
,'Zachmurzenie ogólne [oktanty]'
,'Status pomiaru NOG'  
,'Kierunek wiatru  [°]'
,'Status pomiaru KRWR' 
,'Prędkość wiatru  [m/s]' ######################################
,'Status pomiaru FWR'  
,'Poryw wiatru  [m/s]' 
,'Status pomiaru PORW' 
,'Temperatura powietrza [°C]' ######################################
,'Status pomiaru TEMP' 
,'Temperatura termometru zwilżonego [°C]'
,'Status pomiaru TTZW' 
,'Wskaźnik wentylacji [W/N]' 
,'Wskaźnik lodu [L/W]' 
,'Ciśnienie pary wodnej [hPa]'  
,'Status pomiaru CPW'  
,'Wilgotność względna [%]'
,'Status pomiaru WLGW' 
,'Temperatura punktu rosy [°C]' 
,'Status pomiaru TPTR' 
,'Ciśnienie na pozimie stacji [hPa]'  
,'Status pomiaru PPPS' 
,'Ciśnienie na pozimie morza [hPa]'
,'Status pomiaru PPPM' 
,'Charakterystyka tendencji [kod]' 
,'Wartość tendencji [wartość]'  
,'Status pomiaru APP'  
,'Opad za 6 godzin [mm]'  
,'Status pomiaru WO6G'
,'Rodzaj opadu za 6 godzin [kod]'
,'Status pomiaru ROPT'
,'Pogoda bieżąca [kod]'
,'Pogoda ubiegła [kod]'
,'Zachmurzenie niskie [oktanty]'
,'Status pomiaru CLCM'
,'Chmury CL [kod]'
,'Status pomiaru CHCL'
,'Chmury CL tekstem'
,'Chmury CM [kod]'
,'Status pomiaru CHCM'
,'Chmury CM tekstem'
,'Chmury CH [kod]'
,'Status pomiaru CHCH'
,'Chmury CH tekstem'
,'Stan gruntu [kod]'
,'Status pomiaru SGRN'
,'Niedosyt wilgotności [hPa}'
,'Status pomiaru DEFI'
,'Usłonecznienie'
,'Status pomiaru USLN'
,'Wystąpienie rosy [0/1]'
,'Status pomiaru ROSW'
,'Poryw maksymalny za okres WW [m/s]'
,'Status pomiaru PORK'
,'Godzina wystąpienia porywu'
,'Minuta wystąpienia porywu'
,'Temperatura gruntu -5 [°C]'
,'Status pomiaru TG05'
,'Temperatura gruntu -10 [°C]'
,'Status pomiaru TG10'
,'Temperatura gruntu -20 [°C]'
,'Status pomiaru TG20'
,'Temperatura gruntu -50 [°C]'
,'Status pomiaru TG50'
,'Temperatura gruntu -100 [°C]'
,'Status pomiaru TG100'
,'Temperatura minimalna za 12 godzin  [°C]'
,'Status pomiaru TMIN'
,'Temperatura maksymalna za 12 godzin [°C]'
,'Status pomiaru TMAX'
,'Temperatura minimalna przy gruncie za 12 godzin [°C]'
,'Status pomiaru TGMI'
,'Równoważnik wodny śniegu [mm/cm]'
,'Status pomiaru RWSN'
,'Wysokość pokrywy śnieżnej [cm]'
,'Status pomiaru PKSN'
,'Wysokość świeżo spadłego śniegu  [cm]'
,'Status pomiaru HSS'
,'Wysokość śniegu na poletku [cm]'
,'Status pomiaru GRSN'
,'Gatunek śniegu  [kod]'
,'Ukształtowanie pokrywy [kod]'
,'Wysokość próbki [cm]'
,'Status pomiaru HPRO'
,'Ciężar próbki [g]'
,'Status pomiaru CIPR'
]

# %%
def readWeatherFile(file_name):
    file = '../../Additional Data/Weather/' + file_name
    df = pd.read_csv(filepath_or_buffer = file
                     ,engine='python'
                     ,sep = ','
                     ,header = None
                    )

    df.columns = weather_cols
    return df
# test:
# readWeatherFile('s_t_690_2017.csv')

# %%
# getting list of s_d_t .csv files

import glob
file_names_list = (glob.glob("..\\..\\Additional Data\\Weather\\s_t_*.csv"))
lst=[]

for file_name in file_names_list:
    file_name = file_name[-16:]
    file_name = file_name.replace("\\","")
    lst.append(file_name)
#     print(file_name)
file_names_list = lst
lst=[]

# %%
names_to_drop=[]
for i in file_names_list:
    if(int(i[-8:-4]) < weather_start_year):
        names_to_drop.append(i)
for i in names_to_drop:
    file_names_list.remove(i)
file_names_list
# Out:
# ['s_t_01_2020.csv',
#  's_t_02_2020.csv',
#  's_t_03_2020.csv',
#  's_t_04_2020.csv',
#  's_t_05_2020.csv',
#  's_t_06_2020.csv',
#  's_t_07_2020.csv',
#  's_t_08_2020.csv',
#  's_t_09_2020.csv',
#  's_t_100_2010.csv',
#  's_t_100_2011.csv',
#  's_t_100_2012.csv',
#  's_t_100_2013.csv',
#  's_t_100_2014.csv',
#  's_t_100_2015.csv',
#  's_t_100_2016.csv',
#  's_t_100_2017.csv',
#  's_t_100_2018.csv',
#  's_t_100_2019.csv',
#  's_t_105_2010.csv',
#  's_t_105_2011.csv',
#  's_t_105_2012.csv',
#  's_t_105_2013.csv',
#  's_t_105_2014.csv',
#  's_t_105_2015.csv',
#  's_t_105_2016.csv',
#  's_t_105_2017.csv',
#  's_t_105_2018.csv',
#  's_t_105_2019.csv',
#  's_t_10_2020.csv',
#  's_t_115_2010.csv',
#  's_t_115_2011.csv',
#  's_t_115_2012.csv',
#  's_t_115_2013.csv',
#  's_t_115_2014.csv',
#  's_t_115_2015.csv',
#  's_t_115_2016.csv',
#  's_t_115_2017.csv',
#  's_t_115_2018.csv',
#  's_t_115_2019.csv',
#  's_t_120_2010.csv',
#  's_t_120_2011.csv',
#  's_t_120_2012.csv',
#  's_t_120_2013.csv',
#  's_t_120_2014.csv',
#  's_t_120_2015.csv',
#  's_t_120_2016.csv',
#  's_t_120_2017.csv',
#  's_t_120_2018.csv',
#  's_t_120_2019.csv',
#  's_t_125_2010.csv',
#  's_t_125_2011.csv',
#  's_t_125_2012.csv',
#  's_t_125_2013.csv',
#  's_t_125_2014.csv',
#  's_t_125_2015.csv',
#  's_t_125_2016.csv',
#  's_t_125_2017.csv',
#  's_t_125_2018.csv',
#  's_t_125_2019.csv',
#  's_t_135_2010.csv',
#  's_t_135_2011.csv',
#  's_t_135_2012.csv',
#  's_t_135_2013.csv',
#  's_t_135_2014.csv',
#  's_t_135_2015.csv',
#  's_t_135_2016.csv',
#  's_t_135_2017.csv',
#  's_t_135_2018.csv',
#  's_t_135_2019.csv',
#  's_t_140_2010.csv',
#  's_t_140_2011.csv',
#  's_t_140_2012.csv',
#  's_t_155_2013.csv',
#  's_t_155_2014.csv',
#  's_t_155_2015.csv',
#  's_t_155_2016.csv',
#  's_t_155_2017.csv',
#  's_t_155_2018.csv',
#  's_t_155_2019.csv',
#  's_t_160_2010.csv',
#  's_t_160_2011.csv',
#  's_t_160_2012.csv',
#  's_t_160_2013.csv',
#  's_t_160_2014.csv',
#  's_t_160_2015.csv',
#  's_t_160_2016.csv',
#  's_t_160_2017.csv',
#  's_t_160_2018.csv',
#  's_t_160_2019.csv',
#  's_t_185_2010.csv',
#  's_t_185_2011.csv',
#  's_t_185_2012.csv',
#  's_t_185_2013.csv',
#  's_t_185_2014.csv',
#  's_t_185_2015.csv',
#  's_t_185_2016.csv',
#  's_t_185_2017.csv',
#  's_t_185_2018.csv',
#  's_t_185_2019.csv',
#  's_t_195_2010.csv',
#  's_t_195_2011.csv',
#  's_t_195_2012.csv',
#  's_t_195_2013.csv',
#  's_t_195_2014.csv',
#  's_t_195_2015.csv',
#  's_t_195_2016.csv',
#  's_t_195_2017.csv',
#  's_t_195_2018.csv',
#  's_t_195_2019.csv',
#  's_t_200_2010.csv',
#  's_t_200_2011.csv',
#  's_t_200_2012.csv',
#  's_t_200_2013.csv',
#  's_t_200_2014.csv',
#  's_t_200_2015.csv',
#  's_t_200_2016.csv',
#  's_t_200_2017.csv',
#  's_t_200_2018.csv',
#  's_t_200_2019.csv',
#  's_t_205_2010.csv',
#  's_t_205_2011.csv',
#  's_t_205_2012.csv',
#  's_t_205_2013.csv',
#  's_t_205_2014.csv',
#  's_t_205_2015.csv',
#  's_t_205_2016.csv',
#  's_t_205_2017.csv',
#  's_t_205_2018.csv',
#  's_t_205_2019.csv',
#  's_t_210_2010.csv',
#  's_t_210_2011.csv',
#  's_t_210_2012.csv',
#  's_t_210_2013.csv',
#  's_t_210_2014.csv',
#  's_t_210_2018.csv',
#  's_t_210_2019.csv',
#  's_t_230_2010.csv',
#  's_t_230_2011.csv',
#  's_t_230_2012.csv',
#  's_t_230_2013.csv',
#  's_t_230_2014.csv',
#  's_t_230_2015.csv',
#  's_t_230_2016.csv',
#  's_t_230_2017.csv',
#  's_t_230_2018.csv',
#  's_t_230_2019.csv',
#  's_t_235_2010.csv',
#  's_t_235_2011.csv',
#  's_t_235_2012.csv',
#  's_t_235_2013.csv',
#  's_t_235_2014.csv',
#  's_t_235_2015.csv',
#  's_t_235_2016.csv',
#  's_t_235_2017.csv',
#  's_t_235_2018.csv',
#  's_t_235_2019.csv',
#  's_t_250_2010.csv',
#  's_t_250_2011.csv',
#  's_t_250_2012.csv',
#  's_t_250_2013.csv',
#  's_t_250_2014.csv',
#  's_t_250_2015.csv',
#  's_t_250_2016.csv',
#  's_t_250_2017.csv',
#  's_t_250_2018.csv',
#  's_t_250_2019.csv',
#  's_t_270_2010.csv',
#  's_t_270_2011.csv',
#  's_t_270_2012.csv',
#  's_t_270_2013.csv',
#  's_t_270_2014.csv',
#  's_t_270_2015.csv',
#  's_t_270_2016.csv',
#  's_t_270_2017.csv',
#  's_t_270_2018.csv',
#  's_t_270_2019.csv',
#  's_t_272_2010.csv',
#  's_t_272_2011.csv',
#  's_t_272_2012.csv',
#  's_t_272_2013.csv',
#  's_t_272_2014.csv',
#  's_t_272_2015.csv',
#  's_t_272_2016.csv',
#  's_t_272_2017.csv',
#  's_t_272_2018.csv',
#  's_t_272_2019.csv',
#  's_t_280_2010.csv',
#  's_t_280_2011.csv',
#  's_t_280_2012.csv',
#  's_t_280_2013.csv',
#  's_t_280_2014.csv',
#  's_t_280_2015.csv',
#  's_t_280_2016.csv',
#  's_t_280_2017.csv',
#  's_t_280_2018.csv',
#  's_t_280_2019.csv',
#  's_t_295_2010.csv',
#  's_t_295_2011.csv',
#  's_t_295_2012.csv',
#  's_t_295_2013.csv',
#  's_t_295_2014.csv',
#  's_t_295_2015.csv',
#  's_t_295_2016.csv',
#  's_t_295_2017.csv',
#  's_t_295_2018.csv',
#  's_t_295_2019.csv',
#  's_t_300_2010.csv',
#  's_t_300_2011.csv',
#  's_t_300_2012.csv',
#  's_t_300_2013.csv',
#  's_t_300_2014.csv',
#  's_t_300_2015.csv',
#  's_t_300_2016.csv',
#  's_t_300_2017.csv',
#  's_t_300_2018.csv',
#  's_t_300_2019.csv',
#  's_t_310_2010.csv',
#  's_t_310_2011.csv',
#  's_t_310_2012.csv',
#  's_t_310_2013.csv',
#  's_t_310_2014.csv',
#  's_t_310_2015.csv',
#  's_t_310_2016.csv',
#  's_t_310_2017.csv',
#  's_t_310_2018.csv',
#  's_t_310_2019.csv',
#  's_t_330_2010.csv',
#  's_t_330_2011.csv',
#  's_t_330_2012.csv',
#  's_t_330_2013.csv',
#  's_t_330_2014.csv',
#  's_t_330_2015.csv',
#  's_t_330_2016.csv',
#  's_t_330_2017.csv',
#  's_t_330_2018.csv',
#  's_t_330_2019.csv',
#  's_t_345_2010.csv',
#  's_t_345_2011.csv',
#  's_t_345_2012.csv',
#  's_t_345_2013.csv',
#  's_t_345_2014.csv',
#  's_t_345_2015.csv',
#  's_t_345_2016.csv',
#  's_t_345_2017.csv',
#  's_t_345_2018.csv',
#  's_t_345_2019.csv',
#  's_t_360_2010.csv',
#  's_t_360_2011.csv',
#  's_t_360_2012.csv',
#  's_t_360_2013.csv',
#  's_t_360_2014.csv',
#  's_t_360_2015.csv',
#  's_t_360_2016.csv',
#  's_t_360_2017.csv',
#  's_t_360_2018.csv',
#  's_t_360_2019.csv',
#  's_t_375_2010.csv',
#  's_t_375_2011.csv',
#  's_t_375_2012.csv',
#  's_t_375_2013.csv',
#  's_t_375_2014.csv',
#  's_t_375_2015.csv',
#  's_t_375_2016.csv',
#  's_t_375_2017.csv',
#  's_t_375_2018.csv',
#  's_t_375_2019.csv',
#  's_t_385_2010.csv',
#  's_t_385_2011.csv',
#  's_t_385_2012.csv',
#  's_t_385_2013.csv',
#  's_t_385_2014.csv',
#  's_t_385_2015.csv',
#  's_t_385_2016.csv',
#  's_t_385_2017.csv',
#  's_t_385_2018.csv',
#  's_t_385_2019.csv',
#  's_t_399_2010.csv',
#  's_t_399_2011.csv',
#  's_t_399_2012.csv',
#  's_t_399_2013.csv',
#  's_t_399_2014.csv',
#  's_t_399_2015.csv',
#  's_t_399_2016.csv',
#  's_t_399_2017.csv',
#  's_t_399_2018.csv',
#  's_t_399_2019.csv',
#  's_t_400_2010.csv',
#  's_t_400_2011.csv',
#  's_t_400_2012.csv',
#  's_t_400_2013.csv',
#  's_t_400_2014.csv',
#  's_t_400_2015.csv',
#  's_t_400_2016.csv',
#  's_t_400_2017.csv',
#  's_t_400_2018.csv',
#  's_t_400_2019.csv',
#  's_t_415_2010.csv',
#  's_t_415_2011.csv',
#  's_t_415_2012.csv',
#  's_t_415_2013.csv',
#  's_t_415_2014.csv',
#  's_t_415_2015.csv',
#  's_t_415_2016.csv',
#  's_t_415_2017.csv',
#  's_t_415_2018.csv',
#  's_t_415_2019.csv',
#  's_t_418_2010.csv',
#  's_t_418_2011.csv',
#  's_t_418_2012.csv',
#  's_t_418_2013.csv',
#  's_t_418_2014.csv',
#  's_t_418_2015.csv',
#  's_t_418_2016.csv',
#  's_t_418_2017.csv',
#  's_t_418_2018.csv',
#  's_t_418_2019.csv',
#  's_t_424_2010.csv',
#  's_t_424_2011.csv',
#  's_t_424_2012.csv',
#  's_t_424_2013.csv',
#  's_t_424_2014.csv',
#  's_t_424_2015.csv',
#  's_t_424_2016.csv',
#  's_t_424_2017.csv',
#  's_t_424_2018.csv',
#  's_t_424_2019.csv',
#  's_t_435_2010.csv',
#  's_t_435_2011.csv',
#  's_t_435_2012.csv',
#  's_t_435_2013.csv',
#  's_t_435_2014.csv',
#  's_t_435_2015.csv',
#  's_t_435_2016.csv',
#  's_t_435_2017.csv',
#  's_t_435_2018.csv',
#  's_t_435_2019.csv',
#  's_t_455_2010.csv',
#  's_t_455_2011.csv',
#  's_t_455_2012.csv',
#  's_t_455_2013.csv',
#  's_t_455_2014.csv',
#  's_t_455_2015.csv',
#  's_t_455_2016.csv',
#  's_t_455_2017.csv',
#  's_t_455_2018.csv',
#  's_t_455_2019.csv',
#  's_t_465_2010.csv',
#  's_t_465_2011.csv',
#  's_t_465_2012.csv',
#  's_t_465_2013.csv',
#  's_t_465_2014.csv',
#  's_t_465_2015.csv',
#  's_t_465_2016.csv',
#  's_t_465_2017.csv',
#  's_t_465_2018.csv',
#  's_t_465_2019.csv',
#  's_t_469_2010.csv',
#  's_t_469_2011.csv',
#  's_t_469_2012.csv',
#  's_t_469_2013.csv',
#  's_t_469_2014.csv',
#  's_t_469_2015.csv',
#  's_t_469_2016.csv',
#  's_t_469_2017.csv',
#  's_t_469_2018.csv',
#  's_t_469_2019.csv',
#  's_t_488_2010.csv',
#  's_t_488_2011.csv',
#  's_t_488_2012.csv',
#  's_t_488_2013.csv',
#  's_t_488_2014.csv',
#  's_t_488_2015.csv',
#  's_t_488_2016.csv',
#  's_t_488_2017.csv',
#  's_t_488_2018.csv',
#  's_t_488_2019.csv',
#  's_t_495_2010.csv',
#  's_t_495_2011.csv',
#  's_t_495_2012.csv',
#  's_t_495_2013.csv',
#  's_t_495_2014.csv',
#  's_t_495_2015.csv',
#  's_t_495_2016.csv',
#  's_t_495_2017.csv',
#  's_t_495_2018.csv',
#  's_t_495_2019.csv',
#  's_t_497_2010.csv',
#  's_t_497_2011.csv',
#  's_t_497_2012.csv',
#  's_t_497_2013.csv',
#  's_t_497_2014.csv',
#  's_t_497_2015.csv',
#  's_t_497_2016.csv',
#  's_t_497_2017.csv',
#  's_t_497_2018.csv',
#  's_t_497_2019.csv',
#  's_t_500_2010.csv',
#  's_t_500_2011.csv',
#  's_t_500_2012.csv',
#  's_t_500_2013.csv',
#  's_t_500_2014.csv',
#  's_t_500_2015.csv',
#  's_t_500_2016.csv',
#  's_t_500_2017.csv',
#  's_t_500_2018.csv',
#  's_t_500_2019.csv',
#  's_t_510_2010.csv',
#  's_t_510_2011.csv',
#  's_t_510_2012.csv',
#  's_t_510_2013.csv',
#  's_t_510_2014.csv',
#  's_t_510_2015.csv',
#  's_t_510_2016.csv',
#  's_t_510_2017.csv',
#  's_t_510_2018.csv',
#  's_t_510_2019.csv',
#  's_t_520_2010.csv',
#  's_t_520_2011.csv',
#  's_t_520_2012.csv',
#  's_t_520_2013.csv',
#  's_t_520_2014.csv',
#  's_t_520_2015.csv',
#  's_t_520_2016.csv',
#  's_t_520_2017.csv',
#  's_t_520_2018.csv',
#  's_t_520_2019.csv',
#  's_t_530_2010.csv',
#  's_t_530_2011.csv',
#  's_t_530_2012.csv',
#  's_t_530_2013.csv',
#  's_t_530_2014.csv',
#  's_t_530_2015.csv',
#  's_t_530_2016.csv',
#  's_t_530_2017.csv',
#  's_t_530_2018.csv',
#  's_t_530_2019.csv',
#  's_t_540_2010.csv',
#  's_t_540_2011.csv',
#  's_t_540_2012.csv',
#  's_t_540_2013.csv',
#  's_t_540_2014.csv',
#  's_t_540_2015.csv',
#  's_t_540_2016.csv',
#  's_t_540_2017.csv',
#  's_t_540_2018.csv',
#  's_t_540_2019.csv',
#  's_t_550_2010.csv',
#  's_t_550_2011.csv',
#  's_t_550_2012.csv',
#  's_t_550_2013.csv',
#  's_t_550_2014.csv',
#  's_t_550_2015.csv',
#  's_t_550_2016.csv',
#  's_t_550_2017.csv',
#  's_t_550_2018.csv',
#  's_t_550_2019.csv',
#  's_t_560_2010.csv',
#  's_t_560_2011.csv',
#  's_t_560_2012.csv',
#  's_t_560_2013.csv',
#  's_t_560_2014.csv',
#  's_t_560_2015.csv',
#  's_t_560_2016.csv',
#  's_t_560_2017.csv',
#  's_t_560_2018.csv',
#  's_t_560_2019.csv',
#  's_t_566_2010.csv',
#  's_t_566_2011.csv',
#  's_t_566_2012.csv',
#  's_t_566_2013.csv',
#  's_t_566_2014.csv',
#  's_t_566_2015.csv',
#  's_t_566_2016.csv',
#  's_t_566_2017.csv',
#  's_t_566_2018.csv',
#  's_t_566_2019.csv',
#  's_t_570_2010.csv',
#  's_t_570_2011.csv',
#  's_t_570_2012.csv',
#  's_t_570_2013.csv',
#  's_t_570_2014.csv',
#  's_t_570_2015.csv',
#  's_t_570_2016.csv',
#  's_t_570_2017.csv',
#  's_t_570_2018.csv',
#  's_t_570_2019.csv',
#  's_t_575_2010.csv',
#  's_t_575_2011.csv',
#  's_t_575_2012.csv',
#  's_t_575_2013.csv',
#  's_t_575_2014.csv',
#  's_t_575_2015.csv',
#  's_t_575_2016.csv',
#  's_t_575_2017.csv',
#  's_t_575_2018.csv',
#  's_t_575_2019.csv',
#  's_t_580_2010.csv',
#  's_t_580_2011.csv',
#  's_t_580_2012.csv',
#  's_t_580_2013.csv',
#  's_t_580_2014.csv',
#  's_t_580_2015.csv',
#  's_t_580_2016.csv',
#  's_t_580_2017.csv',
#  's_t_580_2018.csv',
#  's_t_580_2019.csv',
#  's_t_585_2010.csv',
#  's_t_585_2011.csv',
#  's_t_585_2012.csv',
#  's_t_585_2013.csv',
#  's_t_585_2014.csv',
#  's_t_585_2015.csv',
#  's_t_585_2016.csv',
#  's_t_585_2017.csv',
#  's_t_585_2018.csv',
#  's_t_585_2019.csv',
#  's_t_600_2010.csv',
#  's_t_600_2011.csv',
#  's_t_600_2012.csv',
#  's_t_600_2013.csv',
#  's_t_600_2014.csv',
#  's_t_600_2015.csv',
#  's_t_600_2016.csv',
#  's_t_600_2017.csv',
#  's_t_600_2018.csv',
#  's_t_600_2019.csv',
#  's_t_625_2010.csv',
#  's_t_625_2011.csv',
#  's_t_625_2012.csv',
#  's_t_625_2013.csv',
#  's_t_625_2014.csv',
#  's_t_625_2015.csv',
#  's_t_625_2016.csv',
#  's_t_625_2017.csv',
#  's_t_625_2018.csv',
#  's_t_625_2019.csv',
#  's_t_650_2010.csv',
#  's_t_650_2011.csv',
#  's_t_650_2012.csv',
#  's_t_650_2013.csv',
#  's_t_650_2014.csv',
#  's_t_650_2015.csv',
#  's_t_650_2016.csv',
#  's_t_650_2017.csv',
#  's_t_650_2018.csv',
#  's_t_650_2019.csv',
#  's_t_660_2010.csv',
#  's_t_660_2011.csv',
#  's_t_660_2012.csv',
#  's_t_660_2013.csv',
#  's_t_660_2014.csv',
#  's_t_660_2015.csv',
#  's_t_660_2016.csv',
#  's_t_660_2017.csv',
#  's_t_660_2018.csv',
#  's_t_660_2019.csv',
#  's_t_670_2010.csv',
#  's_t_670_2011.csv',
#  's_t_670_2012.csv',
#  's_t_670_2013.csv',
#  's_t_670_2014.csv',
#  's_t_670_2015.csv',
#  's_t_670_2016.csv',
#  's_t_670_2017.csv',
#  's_t_670_2018.csv',
#  's_t_670_2019.csv',
#  's_t_690_2010.csv',
#  's_t_690_2011.csv',
#  's_t_690_2012.csv',
#  's_t_690_2013.csv',
#  's_t_690_2014.csv',
#  's_t_690_2015.csv',
#  's_t_690_2016.csv',
#  's_t_690_2017.csv',
#  's_t_690_2018.csv',
#  's_t_690_2019.csv']

# %%
weatherDF = readWeatherFile(file_names_list[1]).iloc[0:0] #dummy
weatherDF = weatherDF[['Nazwa stacji'
            ,'Rok' 
            ,'Miesiąc' 
            ,'Dzień'
            ,'Godzina' 
            ,'Prędkość wiatru  [m/s]'
            ,'Temperatura powietrza [°C]']]
for file_name in file_names_list:
    weatherDF = weatherDF.append(
        readWeatherFile(file_name)[['Nazwa stacji'
            ,'Rok' 
            ,'Miesiąc' 
            ,'Dzień'
            ,'Godzina' 
            ,'Prędkość wiatru  [m/s]'
            ,'Temperatura powietrza [°C]']]
        ,ignore_index=True
        )
    print(file_name)
weatherDF.isna().sum()
# Out:
# s_t_01_2020.csv
# s_t_02_2020.csv
# s_t_03_2020.csv
# s_t_04_2020.csv
# s_t_05_2020.csv
# s_t_06_2020.csv
# s_t_07_2020.csv
# s_t_08_2020.csv
# s_t_09_2020.csv
# s_t_100_2010.csv
# s_t_100_2011.csv
# s_t_100_2012.csv
# s_t_100_2013.csv
# s_t_100_2014.csv
# s_t_100_2015.csv
# s_t_100_2016.csv
# s_t_100_2017.csv
# s_t_100_2018.csv
# s_t_100_2019.csv
# s_t_105_2010.csv
# s_t_105_2011.csv
# s_t_105_2012.csv
# s_t_105_2013.csv
# s_t_105_2014.csv
# s_t_105_2015.csv
# s_t_105_2016.csv
# s_t_105_2017.csv
# s_t_105_2018.csv
# s_t_105_2019.csv
# s_t_10_2020.csv
# s_t_115_2010.csv
# s_t_115_2011.csv
# s_t_115_2012.csv
# s_t_115_2013.csv
# s_t_115_2014.csv
# s_t_115_2015.csv
# s_t_115_2016.csv
# s_t_115_2017.csv
# s_t_115_2018.csv
# s_t_115_2019.csv
# s_t_120_2010.csv
# s_t_120_2011.csv
# s_t_120_2012.csv
# s_t_120_2013.csv
# s_t_120_2014.csv
# s_t_120_2015.csv
# s_t_120_2016.csv
# s_t_120_2017.csv
# s_t_120_2018.csv
# s_t_120_2019.csv
# s_t_125_2010.csv
# s_t_125_2011.csv
# s_t_125_2012.csv
# s_t_125_2013.csv
# s_t_125_2014.csv
# s_t_125_2015.csv
# s_t_125_2016.csv
# s_t_125_2017.csv
# s_t_125_2018.csv
# s_t_125_2019.csv
# s_t_135_2010.csv
# s_t_135_2011.csv
# s_t_135_2012.csv
# s_t_135_2013.csv
# s_t_135_2014.csv
# s_t_135_2015.csv
# s_t_135_2016.csv
# s_t_135_2017.csv
# s_t_135_2018.csv
# s_t_135_2019.csv
# s_t_140_2010.csv
# s_t_140_2011.csv
# s_t_140_2012.csv
# s_t_155_2013.csv
# s_t_155_2014.csv
# s_t_155_2015.csv
# s_t_155_2016.csv
# s_t_155_2017.csv
# s_t_155_2018.csv
# s_t_155_2019.csv
# s_t_160_2010.csv
# s_t_160_2011.csv
# s_t_160_2012.csv
# s_t_160_2013.csv
# s_t_160_2014.csv
# s_t_160_2015.csv
# s_t_160_2016.csv
# s_t_160_2017.csv
# s_t_160_2018.csv
# s_t_160_2019.csv
# s_t_185_2010.csv
# s_t_185_2011.csv
# s_t_185_2012.csv
# s_t_185_2013.csv
# s_t_185_2014.csv
# s_t_185_2015.csv
# s_t_185_2016.csv
# s_t_185_2017.csv
# s_t_185_2018.csv
# s_t_185_2019.csv
# s_t_195_2010.csv
# s_t_195_2011.csv
# s_t_195_2012.csv
# s_t_195_2013.csv
# s_t_195_2014.csv
# s_t_195_2015.csv
# s_t_195_2016.csv
# s_t_195_2017.csv
# s_t_195_2018.csv
# s_t_195_2019.csv
# s_t_200_2010.csv
# s_t_200_2011.csv
# s_t_200_2012.csv
# s_t_200_2013.csv
# s_t_200_2014.csv
# s_t_200_2015.csv
# s_t_200_2016.csv
# s_t_200_2017.csv
# s_t_200_2018.csv
# s_t_200_2019.csv
# s_t_205_2010.csv
# s_t_205_2011.csv
# s_t_205_2012.csv
# s_t_205_2013.csv
# s_t_205_2014.csv
# s_t_205_2015.csv
# s_t_205_2016.csv
# s_t_205_2017.csv
# s_t_205_2018.csv
# s_t_205_2019.csv
# s_t_210_2010.csv
# s_t_210_2011.csv
# s_t_210_2012.csv
# s_t_210_2013.csv
# s_t_210_2014.csv
# s_t_210_2018.csv
# s_t_210_2019.csv
# s_t_230_2010.csv
# s_t_230_2011.csv
# s_t_230_2012.csv
# s_t_230_2013.csv
# s_t_230_2014.csv
# s_t_230_2015.csv
# s_t_230_2016.csv
# s_t_230_2017.csv
# s_t_230_2018.csv
# s_t_230_2019.csv
# s_t_235_2010.csv
# s_t_235_2011.csv
# s_t_235_2012.csv
# s_t_235_2013.csv
# s_t_235_2014.csv
# s_t_235_2015.csv
# s_t_235_2016.csv
# s_t_235_2017.csv
# s_t_235_2018.csv
# s_t_235_2019.csv
# s_t_250_2010.csv
# s_t_250_2011.csv
# s_t_250_2012.csv
# s_t_250_2013.csv
# s_t_250_2014.csv
# s_t_250_2015.csv
# s_t_250_2016.csv
# s_t_250_2017.csv
# s_t_250_2018.csv
# s_t_250_2019.csv
# s_t_270_2010.csv
# s_t_270_2011.csv
# s_t_270_2012.csv
# s_t_270_2013.csv
# s_t_270_2014.csv
# s_t_270_2015.csv
# s_t_270_2016.csv
# s_t_270_2017.csv
# s_t_270_2018.csv
# s_t_270_2019.csv
# s_t_272_2010.csv
# s_t_272_2011.csv
# s_t_272_2012.csv
# s_t_272_2013.csv
# s_t_272_2014.csv
# s_t_272_2015.csv
# s_t_272_2016.csv
# s_t_272_2017.csv
# s_t_272_2018.csv
# s_t_272_2019.csv
# s_t_280_2010.csv
# s_t_280_2011.csv
# s_t_280_2012.csv
# s_t_280_2013.csv
# s_t_280_2014.csv
# s_t_280_2015.csv
# s_t_280_2016.csv
# s_t_280_2017.csv
# s_t_280_2018.csv
# s_t_280_2019.csv
# s_t_295_2010.csv
# s_t_295_2011.csv
# s_t_295_2012.csv
# s_t_295_2013.csv
# s_t_295_2014.csv
# s_t_295_2015.csv
# s_t_295_2016.csv
# s_t_295_2017.csv
# s_t_295_2018.csv
# s_t_295_2019.csv
# s_t_300_2010.csv
# s_t_300_2011.csv
# s_t_300_2012.csv
# s_t_300_2013.csv
# s_t_300_2014.csv
# s_t_300_2015.csv
# s_t_300_2016.csv
# s_t_300_2017.csv
# s_t_300_2018.csv
# s_t_300_2019.csv
# s_t_310_2010.csv
# s_t_310_2011.csv
# s_t_310_2012.csv
# s_t_310_2013.csv
# s_t_310_2014.csv
# s_t_310_2015.csv
# s_t_310_2016.csv
# s_t_310_2017.csv
# s_t_310_2018.csv
# s_t_310_2019.csv
# s_t_330_2010.csv
# s_t_330_2011.csv
# s_t_330_2012.csv
# s_t_330_2013.csv
# s_t_330_2014.csv
# s_t_330_2015.csv
# s_t_330_2016.csv
# s_t_330_2017.csv
# s_t_330_2018.csv
# s_t_330_2019.csv
# s_t_345_2010.csv
# s_t_345_2011.csv
# s_t_345_2012.csv
# s_t_345_2013.csv
# s_t_345_2014.csv
# s_t_345_2015.csv
# s_t_345_2016.csv
# s_t_345_2017.csv
# s_t_345_2018.csv
# s_t_345_2019.csv
# s_t_360_2010.csv
# s_t_360_2011.csv
# s_t_360_2012.csv
# s_t_360_2013.csv
# s_t_360_2014.csv
# s_t_360_2015.csv
# s_t_360_2016.csv
# s_t_360_2017.csv
# s_t_360_2018.csv
# s_t_360_2019.csv
# s_t_375_2010.csv
# s_t_375_2011.csv
# s_t_375_2012.csv
# s_t_375_2013.csv
# s_t_375_2014.csv
# s_t_375_2015.csv
# s_t_375_2016.csv
# s_t_375_2017.csv
# s_t_375_2018.csv
# s_t_375_2019.csv
# s_t_385_2010.csv
# s_t_385_2011.csv
# s_t_385_2012.csv
# s_t_385_2013.csv
# s_t_385_2014.csv
# s_t_385_2015.csv
# s_t_385_2016.csv
# s_t_385_2017.csv
# s_t_385_2018.csv
# s_t_385_2019.csv
# s_t_399_2010.csv
# s_t_399_2011.csv
# s_t_399_2012.csv
# s_t_399_2013.csv
# s_t_399_2014.csv
# s_t_399_2015.csv
# s_t_399_2016.csv
# s_t_399_2017.csv
# s_t_399_2018.csv
# s_t_399_2019.csv
# s_t_400_2010.csv
# s_t_400_2011.csv
# s_t_400_2012.csv
# s_t_400_2013.csv
# s_t_400_2014.csv
# s_t_400_2015.csv
# s_t_400_2016.csv
# s_t_400_2017.csv
# s_t_400_2018.csv
# s_t_400_2019.csv
# s_t_415_2010.csv
# s_t_415_2011.csv
# s_t_415_2012.csv
# s_t_415_2013.csv
# s_t_415_2014.csv
# s_t_415_2015.csv
# s_t_415_2016.csv
# s_t_415_2017.csv
# s_t_415_2018.csv
# s_t_415_2019.csv
# s_t_418_2010.csv
# s_t_418_2011.csv
# s_t_418_2012.csv
# s_t_418_2013.csv
# s_t_418_2014.csv
# s_t_418_2015.csv
# s_t_418_2016.csv
# s_t_418_2017.csv
# s_t_418_2018.csv
# s_t_418_2019.csv
# s_t_424_2010.csv
# s_t_424_2011.csv
# s_t_424_2012.csv
# s_t_424_2013.csv
# s_t_424_2014.csv
# s_t_424_2015.csv
# s_t_424_2016.csv
# s_t_424_2017.csv
# s_t_424_2018.csv
# s_t_424_2019.csv
# s_t_435_2010.csv
# s_t_435_2011.csv
# s_t_435_2012.csv
# s_t_435_2013.csv
# s_t_435_2014.csv
# s_t_435_2015.csv
# s_t_435_2016.csv
# s_t_435_2017.csv
# s_t_435_2018.csv
# s_t_435_2019.csv
# s_t_455_2010.csv
# s_t_455_2011.csv
# s_t_455_2012.csv
# s_t_455_2013.csv
# s_t_455_2014.csv
# s_t_455_2015.csv
# s_t_455_2016.csv
# s_t_455_2017.csv
# s_t_455_2018.csv
# s_t_455_2019.csv
# s_t_465_2010.csv
# s_t_465_2011.csv
# s_t_465_2012.csv
# s_t_465_2013.csv
# s_t_465_2014.csv
# s_t_465_2015.csv
# s_t_465_2016.csv
# s_t_465_2017.csv
# s_t_465_2018.csv
# s_t_465_2019.csv
# s_t_469_2010.csv
# s_t_469_2011.csv
# s_t_469_2012.csv
# s_t_469_2013.csv
# s_t_469_2014.csv
# s_t_469_2015.csv
# s_t_469_2016.csv
# s_t_469_2017.csv
# s_t_469_2018.csv
# s_t_469_2019.csv
# s_t_488_2010.csv
# s_t_488_2011.csv
# s_t_488_2012.csv
# s_t_488_2013.csv
# s_t_488_2014.csv
# s_t_488_2015.csv
# s_t_488_2016.csv
# s_t_488_2017.csv
# s_t_488_2018.csv
# s_t_488_2019.csv
# s_t_495_2010.csv
# s_t_495_2011.csv
# s_t_495_2012.csv
# s_t_495_2013.csv
# s_t_495_2014.csv
# s_t_495_2015.csv
# s_t_495_2016.csv
# s_t_495_2017.csv
# s_t_495_2018.csv
# s_t_495_2019.csv
# s_t_497_2010.csv
# s_t_497_2011.csv
# s_t_497_2012.csv
# s_t_497_2013.csv
# s_t_497_2014.csv
# s_t_497_2015.csv
# s_t_497_2016.csv
# s_t_497_2017.csv
# s_t_497_2018.csv
# s_t_497_2019.csv
# s_t_500_2010.csv
# s_t_500_2011.csv
# s_t_500_2012.csv
# s_t_500_2013.csv
# s_t_500_2014.csv
# s_t_500_2015.csv
# s_t_500_2016.csv
# s_t_500_2017.csv
# s_t_500_2018.csv
# s_t_500_2019.csv
# s_t_510_2010.csv
# s_t_510_2011.csv
# s_t_510_2012.csv
# s_t_510_2013.csv
# s_t_510_2014.csv
# s_t_510_2015.csv
# s_t_510_2016.csv
# s_t_510_2017.csv
# s_t_510_2018.csv
# s_t_510_2019.csv
# s_t_520_2010.csv
# s_t_520_2011.csv
# s_t_520_2012.csv
# s_t_520_2013.csv
# s_t_520_2014.csv
# s_t_520_2015.csv
# s_t_520_2016.csv
# s_t_520_2017.csv
# s_t_520_2018.csv
# s_t_520_2019.csv
# s_t_530_2010.csv
# s_t_530_2011.csv
# s_t_530_2012.csv
# s_t_530_2013.csv
# s_t_530_2014.csv
# s_t_530_2015.csv
# s_t_530_2016.csv
# s_t_530_2017.csv
# s_t_530_2018.csv
# s_t_530_2019.csv
# s_t_540_2010.csv
# s_t_540_2011.csv
# s_t_540_2012.csv
# s_t_540_2013.csv
# s_t_540_2014.csv
# s_t_540_2015.csv
# s_t_540_2016.csv
# s_t_540_2017.csv
# s_t_540_2018.csv
# s_t_540_2019.csv
# s_t_550_2010.csv
# s_t_550_2011.csv
# s_t_550_2012.csv
# s_t_550_2013.csv
# s_t_550_2014.csv
# s_t_550_2015.csv
# s_t_550_2016.csv
# s_t_550_2017.csv
# s_t_550_2018.csv
# s_t_550_2019.csv
# s_t_560_2010.csv
# s_t_560_2011.csv
# s_t_560_2012.csv
# s_t_560_2013.csv
# s_t_560_2014.csv
# s_t_560_2015.csv
# s_t_560_2016.csv
# s_t_560_2017.csv
# s_t_560_2018.csv
# s_t_560_2019.csv
# s_t_566_2010.csv
# s_t_566_2011.csv
# s_t_566_2012.csv
# s_t_566_2013.csv
# s_t_566_2014.csv
# s_t_566_2015.csv
# s_t_566_2016.csv
# s_t_566_2017.csv
# s_t_566_2018.csv
# s_t_566_2019.csv
# s_t_570_2010.csv
# s_t_570_2011.csv
# s_t_570_2012.csv
# s_t_570_2013.csv
# s_t_570_2014.csv
# s_t_570_2015.csv
# s_t_570_2016.csv
# s_t_570_2017.csv
# s_t_570_2018.csv
# s_t_570_2019.csv
# s_t_575_2010.csv
# s_t_575_2011.csv
# s_t_575_2012.csv
# s_t_575_2013.csv
# s_t_575_2014.csv
# s_t_575_2015.csv
# s_t_575_2016.csv
# s_t_575_2017.csv
# s_t_575_2018.csv
# s_t_575_2019.csv
# s_t_580_2010.csv
# s_t_580_2011.csv
# s_t_580_2012.csv
# s_t_580_2013.csv
# s_t_580_2014.csv
# s_t_580_2015.csv
# s_t_580_2016.csv
# s_t_580_2017.csv
# s_t_580_2018.csv
# s_t_580_2019.csv
# s_t_585_2010.csv
# s_t_585_2011.csv
# s_t_585_2012.csv
# s_t_585_2013.csv
# s_t_585_2014.csv
# s_t_585_2015.csv
# s_t_585_2016.csv
# s_t_585_2017.csv
# s_t_585_2018.csv
# s_t_585_2019.csv
# s_t_600_2010.csv
# s_t_600_2011.csv
# s_t_600_2012.csv
# s_t_600_2013.csv
# s_t_600_2014.csv
# s_t_600_2015.csv
# s_t_600_2016.csv
# s_t_600_2017.csv
# s_t_600_2018.csv
# s_t_600_2019.csv
# s_t_625_2010.csv
# s_t_625_2011.csv
# s_t_625_2012.csv
# s_t_625_2013.csv
# s_t_625_2014.csv
# s_t_625_2015.csv
# s_t_625_2016.csv
# s_t_625_2017.csv
# s_t_625_2018.csv
# s_t_625_2019.csv
# s_t_650_2010.csv
# s_t_650_2011.csv
# s_t_650_2012.csv
# s_t_650_2013.csv
# s_t_650_2014.csv
# s_t_650_2015.csv
# s_t_650_2016.csv
# s_t_650_2017.csv
# s_t_650_2018.csv
# s_t_650_2019.csv
# s_t_660_2010.csv
# s_t_660_2011.csv
# s_t_660_2012.csv
# s_t_660_2013.csv
# s_t_660_2014.csv
# s_t_660_2015.csv
# s_t_660_2016.csv
# s_t_660_2017.csv
# s_t_660_2018.csv
# s_t_660_2019.csv
# s_t_670_2010.csv
# s_t_670_2011.csv
# s_t_670_2012.csv
# s_t_670_2013.csv
# s_t_670_2014.csv
# s_t_670_2015.csv
# s_t_670_2016.csv
# s_t_670_2017.csv
# s_t_670_2018.csv
# s_t_670_2019.csv
# s_t_690_2010.csv
# s_t_690_2011.csv
# s_t_690_2012.csv
# s_t_690_2013.csv
# s_t_690_2014.csv
# s_t_690_2015.csv
# s_t_690_2016.csv
# s_t_690_2017.csv
# s_t_690_2018.csv
# s_t_690_2019.csv
# Nazwa stacji                  0
# Rok                           0
# Miesiąc                       0
# Dzień                         0
# Godzina                       0
# Prędkość wiatru  [m/s]        0
# Temperatura powietrza [°C]    0
# dtype: int64

# %%
weatherDF['Nazwa stacji'].unique()
# Out:
# array(['BIELSKO-BIAŁA', 'ZAKOPANE', 'KASPROWY WIERCH', 'HALA GĄSIENICOWA',
#        'NOWY SĄCZ', 'KROSNO', 'LESKO', 'JELENIA GÓRA', 'ŚNIEŻKA',
#        'KŁODZKO', 'OPOLE', 'RACIBÓRZ', 'CZĘSTOCHOWA',
#        'KATOWICE-MUCHOWIEC', 'KRAKÓW-BALICE', 'KIELCE-SUKÓW', 'TARNÓW',
#        'SANDOMIERZ', 'RZESZÓW-JASIONKA', 'ZAMOŚĆ', 'ZIELONA GÓRA',
#        'LEGNICA', 'LESZNO', 'WROCŁAW-STRACHOWICE', 'KALISZ', 'WIELUŃ',
#        'ŁÓDŹ-LUBLINEK', 'SULEJÓW', 'KOZIENICE', 'LUBLIN-RADAWIEC',
#        'WŁODAWA', 'SŁUBICE', 'GORZÓW WIELKOPOLSKI', 'POZNAŃ-ŁAWICA',
#        'KOŁO', 'PŁOCK', 'WARSZAWA-OKĘCIE', 'SIEDLCE', 'TERESPOL',
#        'ŚWINOUJŚCIE', 'SZCZECIN', 'RESKO-SMÓLSKO', 'PIŁA', 'CHOJNICE',
#        'TORUŃ', 'MŁAWA', 'OLSZTYN', 'MIKOŁAJKI', 'BIAŁYSTOK',
#        'KOŁOBRZEG-DŹWIRZYNO', 'KOSZALIN', 'USTKA', 'ŁEBA', 'LĘBORK',
#        'HEL', 'GDAŃSK-ŚWIBNO', 'ELBLĄG-MILEJEWO', 'KĘTRZYN', 'SUWAŁKI',
#        'KOŁOBRZEG', 'GDAŃSK-PORT PÓŁNOCNY', 'POZNAŃ', 'WARSZAWA',
#        'WROCŁAW', 'ŁÓDŹ', 'KATOWICE'], dtype=object)

# %%
#wybranie top6 zaludnionych
weatherDF = weatherDF[weatherDF['Nazwa stacji'].isin(
['WARSZAWA-OKĘCIE'
,'WROCŁAW-STRACHOWICE'
,'KRAKÓW-BALICE'
,'ŁÓDŹ-LUBLINEK'
,'GDAŃSK-ŚWIBNO'
,'POZNAŃ-ŁAWICA'
])]

# %%
def date_from_row(x):
    y=x['Rok']
    m=x['Miesiąc']
    d=x['Dzień']
    return date(y,m,d)

# %%
weatherDF['DataGodz'] = weatherDF.apply(lambda x: date_from_row(x), axis = 1)
weatherDF['DataGodz'] = pd.to_datetime(weatherDF['DataGodz']) 

weatherDF['DataGodz'] = weatherDF['DataGodz'] + weatherDF['Godzina'].apply(
   lambda x: relativedelta(hours=x)
)
# Out:
# D:\Programy\anaconda\lib\site-packages\pandas\core\arrays\datetimelike.py:1345: PerformanceWarning: Adding/subtracting object-dtype array to DatetimeArray not vectorized
#   PerformanceWarning,

# %%
weatherAvg = weatherDF[
            ['Nazwa stacji',
           'Temperatura powietrza [°C]',
            'DataGodz']
         ].groupby('DataGodz',as_index=False).mean()

# %%
weatherAvg
# Out:
#                  DataGodz  Temperatura powietrza [°C]
# 0     2010-01-01 00:00:00                   -0.300000
# 1     2010-01-01 01:00:00                   -0.500000
# 2     2010-01-01 02:00:00                   -0.400000
# 3     2010-01-01 03:00:00                   -0.300000
# 4     2010-01-01 04:00:00                   -0.200000
# ...                   ...                         ...
# 94963 2020-10-31 19:00:00                    7.016667
# 94964 2020-10-31 20:00:00                    6.816667
# 94965 2020-10-31 21:00:00                    6.616667
# 94966 2020-10-31 22:00:00                    6.283333
# 94967 2020-10-31 23:00:00                    6.083333
#
# [94968 rows x 2 columns]

# %% [markdown]
# #### łączenie pogody z zapotrzebowaniem

# %%
dataAll = pd.merge(dataAll, weatherAvg, how='left',on='DataGodz')

# %% [markdown]
# ### święta z kalendarza

# %%
import holidays
pl_holidays = holidays.Poland()
dataAll['Swieto'] = dataAll['DataGodz'].apply(lambda x: int(x in pl_holidays))

# %% [markdown]
# #### petla godzinowa

# %%
models_num = 24
my_models = [None] * models_num

# %%
# modelData2.where(modelData2['DataGodz'].hour==2)
dataAll[dataAll['Godzina']==0]#['Krajowe zapotrzebowanie na moc']
# dataAll['Godzina']==0
# Out:
# Empty DataFrame
# Columns: [Data, Godzina, Krajowe zapotrzebowanie na moc, Sumaryczna generacja JWCD, Generacja PI, Generacja IRZ, Sumaryczna generacja nJWCD, Krajowe saldo wymiany międzysystemowej równoległej, Krajowe saldo wymiany międzysystemowej nierównoległej, Rok, Miesiac, Dzien, weekDayNum, weekDay, DataGodz, Temperatura powietrza [°C], Swieto]
# Index: []

# %%
starttime = datetime.now()
print('start petli: ' +str(starttime))
for i in range(models_num):
    print('##### startuje dopasowanie modelu dla godziny: ' + str(i))
    my_models[i] = create_model(
        dataAll[dataAll['Godzina'] % 24 ==i %24]['Krajowe zapotrzebowanie na moc']
        ,7
        ,regresor = dataAll[dataAll['Godzina'] % 24 ==i %24][['Temperatura powietrza [°C]','Swieto']]
    )
    print('##### Koniec dopasowania modelu dla godziny: ' + str(i))
    print('#####')
# Out:
# start petli: 2021-03-03 23:14:52.695774
# ##### startuje dopasowanie modelu dla godziny: 0
# Performing stepwise search to minimize aic
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=51481.418, Time=4.91 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=55470.889, Time=0.17 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=52474.963, Time=4.53 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=53897.777, Time=2.90 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=55468.891, Time=1.15 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(2,1,2)(0,0,1)[7] intercept   : AIC=53026.039, Time=4.29 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(2,1,2)(1,0,0)[7] intercept   : AIC=52093.895, Time=4.24 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(2,1,2)(2,0,1)[7] intercept   : AIC=51497.437, Time=8.09 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(2,1,2)(1,0,2)[7] intercept   : AIC=51467.932, Time=8.22 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(2,1,2)(0,0,2)[7] intercept   : AIC=52609.396, Time=7.31 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(2,1,2)(2,0,2)[7] intercept   : AIC=51471.153, Time=9.16 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(1,1,2)(1,0,2)[7] intercept   : AIC=51572.235, Time=7.28 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(2,1,1)(1,0,2)[7] intercept   : AIC=52549.757, Time=7.33 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(3,1,2)(1,0,2)[7] intercept   : AIC=51273.068, Time=8.99 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(3,1,2)(0,0,2)[7] intercept   : AIC=52550.789, Time=7.59 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(3,1,2)(1,0,1)[7] intercept   : AIC=51292.661, Time=5.30 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(3,1,2)(2,0,2)[7] intercept   : AIC=51272.157, Time=9.33 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(3,1,2)(2,0,1)[7] intercept   : AIC=51297.721, Time=7.78 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(3,1,1)(2,0,2)[7] intercept   : AIC=52554.996, Time=8.69 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,2)(2,0,2)[7] intercept   : AIC=51170.707, Time=9.96 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,2)(1,0,2)[7] intercept   : AIC=51208.344, Time=8.23 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,2)(2,0,1)[7] intercept   : AIC=51212.803, Time=9.20 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,2)(1,0,1)[7] intercept   : AIC=51210.889, Time=5.65 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,1)(2,0,2)[7] intercept   : AIC=52349.602, Time=9.62 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,2)(2,0,2)[7] intercept   : AIC=51193.557, Time=11.34 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,3)(2,0,2)[7] intercept   : AIC=51166.473, Time=11.49 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,3)(1,0,2)[7] intercept   : AIC=51227.074, Time=11.16 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,3)(2,0,1)[7] intercept   : AIC=51253.201, Time=10.63 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,3)(1,0,1)[7] intercept   : AIC=51254.341, Time=6.38 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(3,1,3)(2,0,2)[7] intercept   : AIC=52127.488, Time=10.11 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,3)(2,0,2)[7] intercept   : AIC=51048.217, Time=11.68 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,3)(1,0,2)[7] intercept   : AIC=51037.331, Time=11.65 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,3)(0,0,2)[7] intercept   : AIC=52239.893, Time=12.66 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,3)(1,0,1)[7] intercept   : AIC=51044.422, Time=7.84 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,3)(0,0,1)[7] intercept   : AIC=52300.996, Time=6.90 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,3)(2,0,1)[7] intercept   : AIC=51079.470, Time=11.39 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,2)(1,0,2)[7] intercept   : AIC=51206.462, Time=12.49 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,4)(1,0,2)[7] intercept   : AIC=51416.993, Time=16.72 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,4)(1,0,2)[7] intercept   : AIC=52123.684, Time=13.72 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,3)(1,0,2)[7]             : AIC=51024.235, Time=11.45 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,3)(0,0,2)[7]             : AIC=52235.235, Time=12.08 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,3)(1,0,1)[7]             : AIC=inf, Time=6.90 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,3)(2,0,2)[7]             : AIC=51024.378, Time=11.17 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,3)(0,0,1)[7]             : AIC=52299.389, Time=6.13 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,3)(2,0,1)[7]             : AIC=51035.471, Time=9.51 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,3)(1,0,2)[7]             : AIC=51190.656, Time=11.22 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ...
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(3,1,2)(2,0,1)[7] intercept   : AIC=50610.651, Time=8.88 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(3,1,1)(1,0,2)[7] intercept   : AIC=52543.973, Time=8.81 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,2)(1,0,2)[7] intercept   : AIC=50354.818, Time=10.12 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,2)(0,0,2)[7] intercept   : AIC=52018.655, Time=8.05 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,2)(1,0,1)[7] intercept   : AIC=50384.585, Time=6.62 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,2)(2,0,2)[7] intercept   : AIC=50373.138, Time=11.35 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,2)(0,0,1)[7] intercept   : AIC=52777.329, Time=5.66 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,2)(2,0,1)[7] intercept   : AIC=50380.493, Time=9.97 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,1)(1,0,2)[7] intercept   : AIC=52277.349, Time=9.69 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,2)(1,0,2)[7] intercept   : AIC=50394.638, Time=10.27 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,3)(1,0,2)[7] intercept   : AIC=50888.442, Time=11.08 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(3,1,3)(1,0,2)[7] intercept   : AIC=51979.042, Time=10.29 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,1)(1,0,2)[7] intercept   : AIC=51078.369, Time=8.70 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(5,1,3)(1,0,2)[7] intercept   : AIC=50405.228, Time=12.73 sec
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#  ARIMA(4,1,2)(1,0,2)[7]             : AIC=inf, Time=8.21 sec
#
# Best model:  ARIMA(4,1,2)(1,0,2)[7] intercept
# Total fit time: 271.104 seconds
# autoARIMA time: 0:04:31.531207
# (4, 1, 2)
# (1, 0, 2, 7)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# fit time = 0:00:22.213509
# ##### Koniec dopasowania modelu dla godziny: 23
# #####

# %%
import winsound
frequency = 3500  # Set Frequency To 2500 Hertz
duration = 3000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)

# %%
test_start = '2019-04-01'
test_end = '2020-02-29'
weatherAvg['Swieto'] = weatherAvg['DataGodz'].apply(lambda x: int(x in pl_holidays))
weatherTest = weatherAvg[weatherAvg['DataGodz'].between(test_start, test_end)][['Temperatura powietrza [°C]','Swieto']]

# %% [markdown]
# ### Prognozowanie

# %%
forecast_steps = int(2260/24)
print(len(my_models))
forecasted_data=[None]*models_num
for i in range(models_num):
#     print(i)
    forecasted_data[i] = my_models[i].forecast(forecast_steps,
                                              exog = weatherTest[i:forecast_steps*models_num:models_num])
# Out:
# 24
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programy\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
combined_forecasted_data = [None] * forecast_steps * models_num
for j in range(forecast_steps):
    for i in range(models_num):
        combined_forecasted_data[j * models_num + i] = forecasted_data[i].iloc[j]

# %%
combined_forecasted_data = pd.Series(combined_forecasted_data)
combined_forecasted_data
# Out:
# 0       18272.798031
# 1       14839.095602
# 2       14722.449690
# 3       14757.730681
# 4       14484.945588
#             ...
# 2251     9385.241151
# 2252    18596.934493
# 2253    21974.263057
# 2254    21378.928076
# 2255    19935.030756
# Length: 2256, dtype: float64

# %% [markdown]
# ### Obliczanie błędu

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
import datetime
test_data = combineData(test_start, test_end)['Krajowe zapotrzebowanie na moc']
test_data
# Out:
# 0       15162.738
# 1       14675.575
# 2       14593.075
# 3       14671.838
# 4       15037.125
#           ...
# 8036    20608.925
# 8037    20036.225
# 8038    18958.488
# 8039    17730.888
# 8040    16650.150
# Name: Krajowe zapotrzebowanie na moc, Length: 8041, dtype: float64

# %%
sample = 2160
mean_absolute_percentage_error(test_data.iloc[:sample], combined_forecasted_data.iloc[:sample])
# Out:
# 9.658588242467838

# %%
print('czas trwania calosci: ' +str(datetime.datetime.now()-starttime))
# Out:
# czas trwania calosci: 1:01:36.215495

# %%
plt.figure(figsize=[20,5])
test_data.iloc[:sample].plot()
combined_forecasted_data.iloc[:sample].plot()
# Out:
# <AxesSubplot:>
